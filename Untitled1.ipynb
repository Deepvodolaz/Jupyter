# %%
import requests
import xmltodict

url = "http://ru.bookmate.com/XML_daily.asp"
response = requests.get(url)
response
# Out:
# <Response [404]>

# %%
response.content
# Out:
# b'\r\n<!DOCTYPE html>\r\n<html lang="ru" xmlns="http://www.w3.org/1999/xhtml">\r\n<head>\r\n<title>\xd0\x9f\xd0\xbe\xd0\xb3\xd0\xbe\xd0\xb4\xd0\xb0 \xd0\xb2 243 \xd1\x81\xd1\x82\xd1\x80\xd0\xb0\xd0\xbd\xd0\xb0\xd1\x85 \xd0\xbc\xd0\xb8\xd1\x80\xd0\xb0</title>\r\n<script type="application/ld+json">\r\n{\r\n"dateModified": "2022-09-12"\r\n}\r\n</script>\r\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\r\n<meta name="description" content="\xd0\x9f\xd0\xbe\xd0\xb3\xd0\xbe\xd0\xb4\xd0\xb0 \xd0\xb2 \xd0\xbc\xd0\xb8\xd1\x80\xd0\xb5. \xd0\x9d\xd0\xbe\xd0\xb2\xd0\xbe\xd1\x81\xd1\x82\xd0\xb8 \xd0\xbf\xd0\xbe\xd0\xb3\xd0\xbe\xd0\xb4\xd1\x8b \xd0\xb2 \xd0\xbc\xd0\xb8\xd1\x80\xd0\xb5. \xd0\x9f\xd1\x80\xd0\xbe\xd0\xb3\xd0\xbd\xd0\xbe\xd0\xb7 \xd0\xbf\xd0\xbe\xd0\xb3\xd0\xbe\xd0\xb4\xd1\x8b \xd0\xb2 \xd0\xbc\xd0\xb8\xd1\x80\xd0\xb5. \xd0\x9f\xd0\xbe\xd0\xb3\xd0\xbe\xd0\xb4\xd0\xb0 \xd0\xbd\xd0\xb0 \xd0\xba\xd1\x83\xd1\x80\xd0\xbe\xd1\x80\xd1\x82\xd0\xb0\xd1\x85 \xd0\xbc\xd0\x
# ...

# %%
data = xmltodict.parse(response.content)
data
# Out:
# ---------------------------------------------------------------------------
# ExpatError                                Traceback (most recent call last)
# Cell In [9], line 1
# ----> 1 data = xmltodict.parse(response.content)
#       2 data
#
# File C:\Program Files\Python310\lib\site-packages\xmltodict.py:378, in parse(xml_input, encoding, expat, process_namespaces, namespace_separator, disable_entities, process_comments, **kwargs)
#     376     parser.Parse(b'',True)
#     377 else:
# --> 378     parser.Parse(xml_input, True)
#     379 return handler.item
#
# ExpatError: not well-formed (invalid token): line 37, column 92
